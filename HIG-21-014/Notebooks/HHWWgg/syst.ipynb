# %%
import uproot 
from matplotlib import pyplot as plt 
import numpy as np

# %%
file = "/eos/user/a/atishelm/ntuples/HHWWgg_flashgg/January_2021_Production/2017/HHWWyyDNN_WithHggFactor2-200Epochs-3ClassMulticlass_EvenSingleH_2Hgg_withKinWeightCut10_BalanceYields/Signal_cHHH1_2017_all_CategorizedTrees.root"
f = uproot.open(file)
print("trees:")
for tree in f.keys():
    print(tree)
# Out:
# trees:
# b'GluGluToHHTo2G2Qlnu_node_cHHH1_13TeV_HHWWggTag_SL_0;1'
# b'GluGluToHHTo2G2Qlnu_node_cHHH1_13TeV_HHWWggTag_SL_1;1'
# b'GluGluToHHTo2G2Qlnu_node_cHHH1_13TeV_HHWWggTag_SL_2;1'
# b'GluGluToHHTo2G2Qlnu_node_cHHH1_13TeV_HHWWggTag_SL_3;1'
# b'GluGluToHHTo2G2Qlnu_node_cHHH1_13TeV_HHWWggTag_SL_0_MvaShiftUp01sigma;1'
# b'GluGluToHHTo2G2Qlnu_node_cHHH1_13TeV_HHWWggTag_SL_1_MvaShiftUp01sigma;1'
# b'GluGluToHHTo2G2Qlnu_node_cHHH1_13TeV_HHWWggTag_SL_2_MvaShiftUp01sigma;1'
# b'GluGluToHHTo2G2Qlnu_node_cHHH1_13TeV_HHWWggTag_SL_3_MvaShiftUp01sigma;1'
# b'GluGluToHHTo2G2Qlnu_node_cHHH1_13TeV_HHWWggTag_SL_0_SigmaEOverEShiftUp01sigma;1'
# b'GluGluToHHTo2G2Qlnu_node_cHHH1_13TeV_HHWWggTag_SL_1_SigmaEOverEShiftUp01sigma;1'
# b'GluGluToHHTo2G2Qlnu_node_cHHH1_13TeV_HHWWggTag_SL_2_SigmaEOverEShiftUp01sigma;1'
# b'GluGluToHHTo2G2Qlnu_node_cHHH1_13TeV_HHWWggTag_SL_3_SigmaEOverEShiftUp01sigma;1'
# b'GluGluToHHTo2G2Qlnu_node_cHHH1_13TeV_HHWWggTag_SL_0_MaterialCentralBarrelUp01sigma;1'
# ...

# %%
t_nom = f['GluGluToHHTo2G2Qlnu_node_cHHH1_13TeV_HHWWggTag_SL_0']
t_up = f['GluGluToHHTo2G2Qlnu_node_cHHH1_13TeV_HHWWggTag_SL_0_MvaShiftUp01sigma']
t_down = f['GluGluToHHTo2G2Qlnu_node_cHHH1_13TeV_HHWWggTag_SL_0_MvaShiftDown01sigma']

CMS_hgg_mass_nom = t['CMS_hgg_mass'].array()
CMS_hgg_mass_up = t['CMS_hgg_mass'].array()
CMS_hgg_mass_down = t['CMS_hgg_mass'].array()

w_nom, w_up, w_down = 

bins = np.linspace(115,135,81)
fig, ax = plt.subplots()
plt.hist(CMS_hgg_mass_nom, bins = bins, histtype = 'step', label = "nominal")
plt.hist(CMS_hgg_mass_up, bins = bins, histtype = 'step', label = "up")
vals, bins, _ = plt.hist(CMS_hgg_mass_down, bins = bins, histtype = 'step', label = "down")
print("bins",bins)
print("vals",vals)
plt.legend()
plt.show()
# Out:
# bins [115.   115.25 115.5  115.75 116.   116.25 116.5  116.75 117.   117.25
#  117.5  117.75 118.   118.25 118.5  118.75 119.   119.25 119.5  119.75
#  120.   120.25 120.5  120.75 121.   121.25 121.5  121.75 122.   122.25
#  122.5  122.75 123.   123.25 123.5  123.75 124.   124.25 124.5  124.75
#  125.   125.25 125.5  125.75 126.   126.25 126.5  126.75 127.   127.25
#  127.5  127.75 128.   128.25 128.5  128.75 129.   129.25 129.5  129.75
#  130.   130.25 130.5  130.75 131.   131.25 131.5  131.75 132.   132.25
#  132.5  132.75 133.   133.25 133.5  133.75 134.   134.25 134.5  134.75
#  135.  ]
# vals [  9.   3.   5.   5.   7.   8.   7.   8.  12.  16.   7.   9.  13.  21.
#   32.  18.  19.  18.  35.  39.  39.  40.  66.  56.  82.  85. 139. 135.
#  166. 204. 241. 286. 329. 383. 423. 446. 481. 549. 490. 527. 540. 458.
#  451. 432. 380. 338. 266. 219. 183. 157. 116. 100.  75.  65.  60.  42.
#   26.  13.  17.  11.   5.   5.  11.   2.   8.   5.   1.   4.   2.   2.
# ...
